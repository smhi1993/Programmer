# %% [markdown]
# #Program that gets the price of renting house and prints what kind of house is needed.

# %% [markdown]
# #Solution 1

# %%
houses_list = ['Suite House' , 'Apartment House' , 'Villa House' , 'Garden House']
options_list = ['Adequate Facilities' , 'Furnished Facilities']
price_list = [1000 , 1500 , 2000 , 3000 , 3500 , 4000]
for price in price_list:
    for options in options_list:
        for house in houses_list:
            if options == options_list[0] and price <= 2000:
                selected_house = []
                selected_house += [house , options , price]
                print('Your considered Price is' , price , '$.')
                print('Your considered House is' , house , '.')
                print('Your considered Options are' , options , '.')
                print(selected_house)
                print('\n')
            elif options == options_list[1] and price >= 3000:
                selected_house = []
                selected_house += [house , options , price]
                print('Your considered Price is' , price , '$.')
                print('Your considered House is' , house , '.')
                print('Your considered Options are' , options , '.')
                print(selected_house)
                print('\n')
            else:
                continue
# Out:
# Your considered Price is 1000 $.
# Your considered House is Suite House .
# Your considered Options are Adequate Facilities .
# ['Suite House', 'Adequate Facilities', 1000]
#
#
# Your considered Price is 1000 $.
# Your considered House is Apartment House .
# Your considered Options are Adequate Facilities .
# ['Apartment House', 'Adequate Facilities', 1000]
#
#
# Your considered Price is 1000 $.
# Your considered House is Villa House .
# Your considered Options are Adequate Facilities .
# ['Villa House', 'Adequate Facilities', 1000]
#
#
# Your considered Price is 1000 $.
# Your considered House is Garden House .
# Your considered Options are Adequate Facilities .
# ['Garden House', 'Adequate Facilities', 1000]
#
#
# Your considered Price is 1500 $.
# Your considered House is Suite House .
# Your considered Options are Adequate Facilities .
# ['Suite House', 'Adequate Facilities', 1500]
#
#
# Your considered Price is 1500 $.
# Your considered House is Apartment House .
# Your considered Options are Adequate Facilities .
# ['Apartment House', 'Adequate Facilities', 1500]
#
#
# Your considered Price is 1500 $.
# Your considered House is Villa House .
# Your considered Options are Adequate Facilities .
# ['Villa House', 'Adequate Facilities', 1500]
#
#
# Your considered Price is 1500 $.
# Your considered House is Garden House .
# Your considered Options are Adequate Facilities .
# ['Garden House', 'Adequate Facilities', 1500]
#
#
# Your considered Price is 2000 $.
# Your considered House is Suite House .
# Your considered Options are Adequate Facilities .
# ['Suite House', 'Adequate Facilities', 2000]
#
#
# Your considered Price is 2000 $.
# Your considered House is Apartment House .
# Your considered Options are Adequate Facilities .
# ['Apartment House', 'Adequate Facilities', 2000]
#
#
# Your considered Price is 2000 $.
# Your considered House is Villa House .
# Your considered Options are Adequate Facilities .
# ['Villa House', 'Adequate Facilities', 2000]
#
#
# Your considered Price is 2000 $.
# Your considered House is Garden House .
# Your considered Options are Adequate Facilities .
# ['Garden House', 'Adequate Facilities', 2000]
#
#
# Your considered Price is 3000 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# ['Suite House', 'Furnished Facilities', 3000]
#
#
# Your considered Price is 3000 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# ['Apartment House', 'Furnished Facilities', 3000]
#
#
# Your considered Price is 3000 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# ['Villa House', 'Furnished Facilities', 3000]
#
#
# Your considered Price is 3000 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# ['Garden House', 'Furnished Facilities', 3000]
#
#
# Your considered Price is 3500 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# ['Suite House', 'Furnished Facilities', 3500]
#
#
# Your considered Price is 3500 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# ['Apartment House', 'Furnished Facilities', 3500]
#
#
# Your considered Price is 3500 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# ['Villa House', 'Furnished Facilities', 3500]
#
#
# Your considered Price is 3500 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# ['Garden House', 'Furnished Facilities', 3500]
#
#
# Your considered Price is 4000 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# ['Suite House', 'Furnished Facilities', 4000]
#
#
# Your considered Price is 4000 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# ['Apartment House', 'Furnished Facilities', 4000]
#
#
# Your considered Price is 4000 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# ['Villa House', 'Furnished Facilities', 4000]
#
#
# Your considered Price is 4000 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# ['Garden House', 'Furnished Facilities', 4000]

# %% [markdown]
# #Solution 2

# %%
houses_list = [('Suite House' , '50m' , 'Adequate Facilities' , 1500) , ('Suite House' , '75m' , 'Furnished Facilities' , 2200) , ('Apartment House', '150m' , 'Adequate Facilities' , 2500) , ('Apartment House', '180m', 'Furnished Facilities' , 3200) , ('Villa House', '250m' , 'Adequate Facilities' , 3500) , ('Villa House', '300m' , 'Furnished Facilities' , 4800) , ('Garden House', '500m' , 'Adequate Facilities' , 5600) , ('Garden House', '600m' , 'Furnished Facilities' , 7500)]
print(houses_list)
options_list = ['Adequate Facilities' , 'Furnished Facilities']
print('Available Facilities are:')
print('0 =' , options_list[0])
print('1 =' , options_list[1])
print('\n')
j = 0
for i in houses_list:
    if houses_list[j][3] < 2000:
        if houses_list[j][2] == options_list[0]:
            selected_house = houses_list[j]
            print('Your considered Price is' , houses_list[j][3] , '$.')
            print('Your considered Options are' , options_list[0] , '.')
            print('Your considered House is' , selected_house , '.')
            print('\n')
            j += 1
        else:
            j += 1
    elif 3000 <= houses_list[j][3]:
        if houses_list[j][2] == options_list[1]:
            selected_house = houses_list[j]
            print('Your considered Price is' , houses_list[j][3] , '$.')
            print('Your considered Options are' , options_list[1] , '.')
            print('Your considered House is' , selected_house , '.')
            print('\n')
            j += 1
        else:
            j += 1
    else:
        j += 1
# Out:
# [('Suite House', '50m', 'Adequate Facilities', 1500), ('Suite House', '75m', 'Furnished Facilities', 2200), ('Apartment House', '150m', 'Adequate Facilities', 2500), ('Apartment House', '180m', 'Furnished Facilities', 3200), ('Villa House', '250m', 'Adequate Facilities', 3500), ('Villa House', '300m', 'Furnished Facilities', 4800), ('Garden House', '500m', 'Adequate Facilities', 5600), ('Garden House', '600m', 'Furnished Facilities', 7500)]
# Available Facilities are:
# 0 = Adequate Facilities
# 1 = Furnished Facilities
#
#
# Your considered Price is 1500 $.
# Your considered Options are Adequate Facilities .
# Your considered House is ('Suite House', '50m', 'Adequate Facilities', 1500) .
#
#
# Your considered Price is 3200 $.
# Your considered Options are Furnished Facilities .
# Your considered House is ('Apartment House', '180m', 'Furnished Facilities', 3200) .
#
#
# Your considered Price is 4800 $.
# Your considered Options are Furnished Facilities .
# Your considered House is ('Villa House', '300m', 'Furnished Facilities', 4800) .
#
#
# Your considered Price is 7500 $.
# Your considered Options are Furnished Facilities .
# Your considered House is ('Garden House', '600m', 'Furnished Facilities', 7500) .

# %% [markdown]
# #Solution 3

# %%
houses_list = [['Suite House' , 'Adequate Facilities' , 1500] , ['Suite House' , 'Furnished Facilities' , 2200] , ['Apartment House', 'Adequate Facilities' , 2500] , ['Apartment House' , 'Furnished Facilities' , 3200] , ['Villa House', 'Adequate Facilities' , 3500] , ['Villa House' , 'Furnished Facilities' , 4800] , ['Garden House' , 'Adequate Facilities' , 5600] , ['Garden House' , 'Furnished Facilities' , 7500]]
print('Available Houses list is:')
print(houses_list)
print('\n')
houses_type = ['Suite House' , 'Apartment House' , 'Villa House' , 'Garden House']
options_list = ['Adequate Facilities' , 'Furnished Facilities']
price_list = [1000 , 1500 , 2000 , 2200 , 2500 , 3000 , 3200 , 3500 , 4000 , 4500 , 4800 , 5000 , 5600 , 7500]
for price in price_list:
    for options in options_list:
        for house in houses_type:
            if options == options_list[0] and price <= 2000:
                wished_house = []
                wished_house += [house , options , price]
                print('Your considered Price is' , price , '$.')
                print('Your considered House is' , house , '.')
                print('Your considered Options are' , options , '.')
                print('Your Wished House is:')
                print(wished_house)
                if wished_house in houses_list:
                    print('Nice! Your Wished House is available!')
                    print('\n')
                    print('---------------------------------------------------------------')
                    print('\n')
                else:
                    print('Unlucky! Your Wished House is not available!')
                    print('\n')
                    print('---------------------------------------------------------------')
                    print('\n')
            elif options == options_list[1] and price >= 3000:
                wished_house = []
                wished_house += [house , options , price]
                print('Your considered Price is' , price , '$.')
                print('Your considered House is' , house , '.')
                print('Your considered Options are' , options , '.')
                print('Your Wished House is:')
                print(wished_house)
                if wished_house in houses_list:
                    print('Nice! Your Wished House is available!')
                    print('\n')
                    print('---------------------------------------------------------------')
                    print('\n')
                else:
                     print('Unlucky! Your Wished House is not available!')
                     print('\n')
                     print('---------------------------------------------------------------')
                     print('\n')
            else:
                print('Unfortunately Available Houses didn\'t match your requirements!')
                print('\n')
                print('---------------------------------------------------------------')
                print('\n')
# Out:
# Available Houses list is:
# [['Suite House', 'Adequate Facilities', 1500], ['Suite House', 'Furnished Facilities', 2200], ['Apartment House', 'Adequate Facilities', 2500], ['Apartment House', 'Furnished Facilities', 3200], ['Villa House', 'Adequate Facilities', 3500], ['Villa House', 'Furnished Facilities', 4800], ['Garden House', 'Adequate Facilities', 5600], ['Garden House', 'Furnished Facilities', 7500]]
#
#
# Your considered Price is 1000 $.
# Your considered House is Suite House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Suite House', 'Adequate Facilities', 1000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 1000 $.
# Your considered House is Apartment House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Apartment House', 'Adequate Facilities', 1000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 1000 $.
# Your considered House is Villa House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Villa House', 'Adequate Facilities', 1000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 1000 $.
# Your considered House is Garden House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Garden House', 'Adequate Facilities', 1000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 1500 $.
# Your considered House is Suite House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Suite House', 'Adequate Facilities', 1500]
# Nice! Your Wished House is available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 1500 $.
# Your considered House is Apartment House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Apartment House', 'Adequate Facilities', 1500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 1500 $.
# Your considered House is Villa House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Villa House', 'Adequate Facilities', 1500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 1500 $.
# Your considered House is Garden House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Garden House', 'Adequate Facilities', 1500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 2000 $.
# Your considered House is Suite House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Suite House', 'Adequate Facilities', 2000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 2000 $.
# Your considered House is Apartment House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Apartment House', 'Adequate Facilities', 2000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 2000 $.
# Your considered House is Villa House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Villa House', 'Adequate Facilities', 2000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 2000 $.
# Your considered House is Garden House .
# Your considered Options are Adequate Facilities .
# Your Wished House is:
# ['Garden House', 'Adequate Facilities', 2000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3000 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 3000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3000 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 3000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3000 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 3000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3000 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 3000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3200 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 3200]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3200 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 3200]
# Nice! Your Wished House is available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3200 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 3200]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3200 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 3200]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3500 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 3500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3500 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 3500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3500 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 3500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 3500 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 3500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4000 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 4000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4000 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 4000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4000 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 4000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4000 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 4000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4500 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 4500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4500 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 4500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4500 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 4500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4500 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 4500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4800 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 4800]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4800 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 4800]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4800 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 4800]
# Nice! Your Wished House is available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 4800 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 4800]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 5000 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 5000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 5000 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 5000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 5000 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 5000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 5000 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 5000]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 5600 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 5600]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 5600 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 5600]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 5600 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 5600]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 5600 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 5600]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Unfortunately Available Houses didn't match your requirements!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 7500 $.
# Your considered House is Suite House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Suite House', 'Furnished Facilities', 7500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 7500 $.
# Your considered House is Apartment House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Apartment House', 'Furnished Facilities', 7500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 7500 $.
# Your considered House is Villa House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Villa House', 'Furnished Facilities', 7500]
# Unlucky! Your Wished House is not available!
#
#
# ---------------------------------------------------------------
#
#
# Your considered Price is 7500 $.
# Your considered House is Garden House .
# Your considered Options are Furnished Facilities .
# Your Wished House is:
# ['Garden House', 'Furnished Facilities', 7500]
# Nice! Your Wished House is available!
#
#
# ---------------------------------------------------------------
